# %%
import scipy.io as sio
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.signal
from scipy.signal import hilbert, chirp
from scipy import signal

# %%
data= sio.loadmat("../content/source_tmseries.mat")

# %%
sorted(data.keys())
# Out:
# ['__globals__', '__header__', '__version__', 'source_tmseries']

# %%
print(data['source_tmseries'])
# Out:
# [[(array([[[ 7.04512177e-03, -1.31115367e-02, -1.48753608e-02, ...,
#            -8.27643078e-04, -8.55315680e-03, -8.08116170e-03],
#           [-1.76383500e+00,  3.94047072e+00,  2.48894786e+00, ...,
#            -7.47074989e-01, -1.90518398e+00,  1.60251978e-01],
#           [-3.33773877e+00,  2.48942414e+00,  1.24664215e+00, ...,
#            -9.83611535e-01, -3.64085078e+00, -1.06214711e+00],
#           ...,
#           [-6.62822961e-02,  1.67259733e-02,  1.21882049e-02, ...,
#            -2.85033427e-02, -1.06533445e-02, -1.32954691e-02],
#           [-5.12939010e-02, -9.20343561e-02, -3.78996881e-02, ...,
#            -2.76718992e-02, -1.86727883e-02,  4.98966154e-03],
#           [ 4.36286469e-02,  1.36606354e-01,  1.01319159e-01, ...,
#             4.59105073e-02,  6.37132976e-02,  5.18985365e-02]],
#
#          [[ 3.49648179e-01,  7.90171734e-01,  4.17561523e-01, ...,
#             4.11399986e-01,  3.08171507e-01,  2.53572395e-01],
# ...

# %%
print(data['source_tmseries'].dtype)
# Out:
# [('prestim_rare', 'O'), ('prestim_frequent', 'O'), ('poststim_rare', 'O'), ('poststim_frequent', 'O')]

# %%
data['source_tmseries'].shape
# Out:
# (1, 1)

# %%
pre_rare = data['source_tmseries'][0,0]['prestim_rare']
pre_freq = data['source_tmseries'][0,0]['prestim_frequent']
post_rare = data['source_tmseries'][0,0]['poststim_rare']
post_freq = data['source_tmseries'][0,0]['poststim_frequent']

# %%
data['source_tmseries'][0,0]['prestim_rare']
# Out:
# array([[[ 7.04512177e-03, -1.31115367e-02, -1.48753608e-02, ...,
#          -8.27643078e-04, -8.55315680e-03, -8.08116170e-03],
#         [-1.76383500e+00,  3.94047072e+00,  2.48894786e+00, ...,
#          -7.47074989e-01, -1.90518398e+00,  1.60251978e-01],
#         [-3.33773877e+00,  2.48942414e+00,  1.24664215e+00, ...,
#          -9.83611535e-01, -3.64085078e+00, -1.06214711e+00],
#         ...,
#         [-6.62822961e-02,  1.67259733e-02,  1.21882049e-02, ...,
#          -2.85033427e-02, -1.06533445e-02, -1.32954691e-02],
#         [-5.12939010e-02, -9.20343561e-02, -3.78996881e-02, ...,
#          -2.76718992e-02, -1.86727883e-02,  4.98966154e-03],
#         [ 4.36286469e-02,  1.36606354e-01,  1.01319159e-01, ...,
#           4.59105073e-02,  6.37132976e-02,  5.18985365e-02]],
#
#        [[ 3.49648179e-01,  7.90171734e-01,  4.17561523e-01, ...,
#           4.11399986e-01,  3.08171507e-01,  2.53572395e-01],
#         [-1.11236147e+02,  5.76310222e+02,  5.10091484e+02, ...,
# ...

# %%
print("shape of prestim_rare : " , pre_rare.shape)
print("shape of prestim_frequent : " , pre_freq.shape)
print("shape of poststim_rare : " , post_rare.shape)
print("shape of poststim_frequent : " , post_freq.shape)
# Out:
# shape of prestim_rare :  (801, 10, 8)
# shape of prestim_frequent :  (801, 8, 10)
# shape of poststim_rare :  (801, 10, 8)
# shape of poststim_frequent :  (801, 9, 10)

# %%
##pre rare
pre_rare_1 = pre_rare[:,0,:]
pre_rare_2 = pre_rare[:,1,:]
pre_rare_3 = pre_rare[:,2,:]
pre_rare_4 = pre_rare[:,3,:]
pre_rare_5 = pre_rare[:,4,:]
pre_rare_6  = pre_rare[: ,5,:]
pre_rare_7 = pre_rare[:,6,:]
pre_rare_8 = pre_rare[:,7,:]
pre_rare_9 = pre_rare[:,8,:]
pre_rare_10 = pre_rare[:,9,:]

# %%
##pre_freq
pre_freq_1 = pre_freq[:,0,:]
pre_freq_2 = pre_freq[:,1,:]
pre_freq_3 = pre_freq[:,2,:]
pre_freq_4  = pre_freq[:,3,:]
pre_freq_5 = pre_freq[:,4,:]
pre_freq_6 = pre_freq[:,5,:]
pre_freq_7 = pre_freq[:,6,:]
pre_freq_8 = pre_freq[:,7,:]

# %%
##post rare
post_rare_1 = post_rare[:,0,:]
post_rare_2 = post_rare[:,1,:]
post_rare_3 = post_rare[:,2,:]
post_rare_4 = post_rare[:,3,:]
post_rare_5 = post_rare[:,4,:]
post_rare_6  = post_rare[: ,5,:]
post_rare_7 = post_rare[:,6,:]
post_rare_8 = post_rare[:,7,:]
post_rare_9 = post_rare[:,8,:]
post_rare_10 = post_rare[:,9,:]

# %%
##post_freq
post_freq_1 = post_freq[:,0,:]
post_freq_2 = post_freq[:,1,:]
post_freq_3 = post_freq[:,2,:]
post_freq_4  = post_freq[:,3,:]
post_freq_5 = post_freq[:,4,:]
post_freq_6 = post_freq[:,5,:]
post_freq_7 = post_freq[:,6,:]
post_freq_8 = post_freq[:,7,:]
post_freq_9 = post_freq[:,8,:]

# %%
pre_rare_1.shape
# Out:
# (801, 8)

# %%
df_rare_1_pre = pd.DataFrame(pre_rare_1, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_2_pre = pd.DataFrame(pre_rare_2, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_3_pre = pd.DataFrame(pre_rare_3, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_4_pre = pd.DataFrame(pre_rare_4, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_5_pre = pd.DataFrame(pre_rare_5, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_6_pre = pd.DataFrame(pre_rare_6, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_7_pre = pd.DataFrame(pre_rare_7, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_8_pre = pd.DataFrame(pre_rare_8, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_9_pre = pd.DataFrame(pre_rare_9, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_10_pre = pd.DataFrame(pre_rare_10, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])

# %%
df_freq_1_pre = pd.DataFrame(pre_freq_1, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_2_pre = pd.DataFrame(pre_freq_2, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_3_pre = pd.DataFrame(pre_freq_3, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_4_pre = pd.DataFrame(pre_freq_4, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_5_pre = pd.DataFrame(pre_freq_5, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_6_pre = pd.DataFrame(pre_freq_6, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_7_pre = pd.DataFrame(pre_freq_7, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_8_pre = pd.DataFrame(pre_freq_8, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])

# %%
df_rare_1_post = pd.DataFrame(post_rare_1, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_2_post = pd.DataFrame(post_rare_2, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_3_post = pd.DataFrame(post_rare_3, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_4_post = pd.DataFrame(post_rare_4, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_5_post = pd.DataFrame(post_rare_5, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_6_post = pd.DataFrame(post_rare_6, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_7_post = pd.DataFrame(post_rare_7, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_8_post = pd.DataFrame(post_rare_8, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_9_post = pd.DataFrame(post_rare_9, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])
df_rare_10_post = pd.DataFrame(post_rare_10, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H'])


df_freq_1_post = pd.DataFrame(post_freq_1, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_2_post = pd.DataFrame(post_freq_2, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_3_post = pd.DataFrame(post_freq_3, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_4_post = pd.DataFrame(post_freq_4, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_5_post = pd.DataFrame(post_freq_5, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_6_post = pd.DataFrame(post_freq_6, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_7_post = pd.DataFrame(post_freq_7, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_8_post = pd.DataFrame(post_freq_8, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])
df_freq_9_post = pd.DataFrame(post_freq_9, columns = ['A','B','C' , 'D','E' , 'F' , 'G' , 'H' , 'I' , 'J'])

# %%
fig, axs = plt.subplots(4,2 , figsize=(10, 15))

axs[0, 0].plot(df_rare_1_pre['A'])
axs[0, 0].set_title('A')
axs[0, 1].plot(df_rare_1_pre['B'])
axs[0, 1].set_title('B')
axs[1, 0].plot(df_rare_1_pre['C'])
axs[1, 0].set_title('C')
axs[1, 1].plot(df_rare_1_pre['D'])
axs[1, 1].set_title('D')
axs[2, 0].plot(df_rare_1_pre['E'])
axs[2, 0].set_title('E')
axs[2, 1].plot(df_rare_1_pre['F'])
axs[2, 1].set_title('F')
axs[3, 0].plot(df_rare_1_pre['G'])
axs[3, 0].set_title('G')
axs[3, 1].plot(df_rare_1_pre['H'])
axs[3, 1].set_title('H')
plt.suptitle("pre stimulus data of region-1 in rare perceivers")
plt.show()

# %%
plt.plot(df_rare_1_pre['A'])
plt.plot(df_rare_1_pre['B'])
plt.plot(df_rare_1_pre['C'])
plt.plot(df_rare_1_pre['D'])
plt.plot(df_rare_1_pre['E'])
plt.plot(df_rare_1_pre['F'])
plt.plot(df_rare_1_pre['G'])
plt.plot(df_rare_1_pre['H'])

# %%
plt.plot(df_rare_1_pre['A'])
plt.plot(df_rare_1_pre['B'])
plt.plot(df_rare_1_pre['C'])
plt.plot(df_rare_1_pre['D'])
plt.plot(df_rare_1_pre['E'])
plt.plot(df_rare_1_pre['F'])
plt.plot(df_rare_1_pre['G'])
plt.plot(df_rare_1_pre['H'])

# %%
plt.plot(df_rare_2_pre['A'])
plt.plot(df_rare_2_pre['B'])
plt.plot(df_rare_2_pre['C'])
plt.plot(df_rare_2_pre['D'])
plt.plot(df_rare_2_pre['E'])
plt.plot(df_rare_2_pre['F'])
plt.plot(df_rare_2_pre['G'])
plt.plot(df_rare_2_pre['H'])

# %%
plt.plot(df_rare_3_pre['A'])
plt.plot(df_rare_3_pre['B'])
plt.plot(df_rare_3_pre['C'])
plt.plot(df_rare_3_pre['D'])
plt.plot(df_rare_3_pre['E'])
plt.plot(df_rare_3_pre['F'])
plt.plot(df_rare_3_pre['G'])
plt.plot(df_rare_3_pre['H'])

# %%
plt.plot(df_rare_4_pre['A'])
plt.plot(df_rare_4_pre['B'])
plt.plot(df_rare_4_pre['C'])
plt.plot(df_rare_4_pre['D'])
plt.plot(df_rare_4_pre['E'])
plt.plot(df_rare_4_pre['F'])
plt.plot(df_rare_4_pre['G'])
plt.plot(df_rare_4_pre['H'])

# %%
df_freq_1_pre
# Out:
#               A           B            C           D          E           F  \
# 0      3.604776    4.515391     5.723530    2.084134   0.660684    5.726446
# 1     41.372677 -172.599179  -120.612791  134.612798 -25.824081   31.204722
# 2     77.541517 -344.120832  -248.788052  259.690211 -50.464657   57.821950
# 3    110.593278 -504.747265  -380.471352  370.290115 -71.504086   86.542275
# 4    139.167463 -649.739026  -517.002291  460.210817 -87.356153  117.995434
# ..          ...         ...          ...         ...        ...         ...
# 796 -194.042028  443.210415  1294.050099  347.026439 -35.410702  662.770332
# 797 -148.556298  348.596400   986.950576  273.158781 -21.279156  526.548511
# 798 -100.468581  240.189365   665.240425  188.772633 -11.360866  365.719159
# 799  -50.666103  122.209263   333.695980   97.111317  -4.500012  187.601977
# 800   -0.012934   -0.672926    -2.793022    1.731913   0.755031    0.568584
#
#               G           H           I           J
# ...

# %%
def compute_similarity(ref_rec,input_rec,weightage=[0.33,0.33,0.33]):
    ## Time domain similarity
    ref_time = np.correlate(ref_rec,ref_rec)    
    inp_time = np.correlate(ref_rec,input_rec)
    diff_time = abs(ref_time-inp_time)

    ## Freq domain similarity
    ref_freq = np.correlate(np.fft.fft(ref_rec),np.fft.fft(ref_rec)) 
    inp_freq = np.correlate(np.fft.fft(ref_rec),np.fft.fft(input_rec))
    diff_freq = abs(ref_freq-inp_freq)

    ## Power similarity
    ref_power = np.sum(ref_rec**2)
    inp_power = np.sum(input_rec**2)
    diff_power = abs(ref_power-inp_power)

    return float(weightage[0]*diff_time+weightage[1]*diff_freq+weightage[2]*diff_power)

# %%
corr_coeff_0 = df_rare_1_pre['A'].corr(df_rare_1_pre['B'])

# %%
print(corr_coeff_0)
# Out:
# 0.04196075078540516

# %%
count=0
for i in df_rare_1_pre['A']:
    count=count+6*i
print(count)
# Out:
# 101.19208126971314

# %%
count=0
for i in df_rare_2_pre['A']:
    count=count+6*i
print(count)
# Out:
# 30887.350258406856

# %%
count=0
for i in df_rare_3_pre['A']:
    count=count+6*i
print(count)
# Out:
# 5768.261972706547

# %%
plt.figure(figsize=(13, 6))
sns.heatmap(df_rare_1_pre.corr(), vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
##plt.xticks(rotation=30, horizontalalignment='right')
plt.show()

# %%
plt.figure(figsize=(13, 6))
sns.heatmap(df_rare_2_pre.corr(), vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
##plt.xticks(rotation=30, horizontalalignment='right')
plt.show()

# %%
plt.figure(figsize=(13, 6))
sns.heatmap(df_freq_1_pre.corr(), vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
##plt.xticks(rotation=30, horizontalalignment='right')
plt.show()

# %%
plt.figure(figsize=(13, 6))
sns.heatmap(df_freq_2_pre.corr(), vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
##plt.xticks(rotation=30, horizontalalignment='right')
plt.show()

# %%
plt.boxplot([df_rare_1_pre['A'], df_rare_1_pre['B'] , df_rare_1_pre['C'], df_rare_1_pre['D'],df_rare_1_pre['E'], df_rare_1_pre['F'], df_rare_1_pre['G'], df_rare_1_pre['H']])
plt.xticks([1,2,3,4,5,6 , 7 ,8], ['A', 'B','C', 'D','E', 'F' , 'G','H'], size = 'small', color = 'k')
plt.show()

# %%
df_rare_1_pre.describe()
# Out:
#                 A           B           C           D           E           F  \
# count  801.000000  801.000000  801.000000  801.000000  801.000000  801.000000
# mean     0.021055    0.200168    0.152892    0.101733    0.072617    0.082448
# std      1.306324    2.715027    2.200823    1.651627    1.482473    1.549951
# min     -3.280422   -6.170456   -5.499580   -3.883423   -4.108898   -3.887299
# 25%     -0.929792   -1.672316   -1.296441   -0.967387   -0.814807   -0.865737
# 50%      0.094692   -0.052656    0.185564    0.224698    0.204940    0.194732
# 75%      0.922432    1.767947    1.460205    1.111163    1.120423    1.243916
# max      3.105150    7.503135    6.331360    4.870120    4.127232    3.191433
#
#                 G           H
# count  801.000000  801.000000
# mean     0.100587    0.089234
# std      1.766358    1.546694
# min     -4.551557   -3.839581
# 25%     -1.055953   -0.973636
# 50%      0.256165    0.241937
# 75%      1.336807    1.156315
# ...

# %%
fig = sns.kdeplot(df_rare_1_pre['A'], color="r")
fig = sns.kdeplot(df_rare_1_pre['B'], color="b")
fig = sns.kdeplot(df_rare_1_pre['C'], color="g")
fig = sns.kdeplot(df_rare_1_pre['D'], color="y")
fig = sns.kdeplot(df_rare_1_pre['E'], color="r")
fig = sns.kdeplot(df_rare_1_pre['F'], color="r")
fig = sns.kdeplot(df_rare_1_pre['G'], color="r")
fig = sns.kdeplot(df_rare_1_pre['H'], color="b")

# %% [markdown]
# <font color='red'> <font size=5>calculated mean of all trials

# %% [markdown]
# shape of prestim_rare :  (801, 10, 8)
# shape of prestim_frequent :  (801, 8, 10)
# shape of poststim_rare :  (801, 10, 8)
# shape of poststim_frequent :  (801, 9, 10)

# %%
df_rare_1_pre['mean'] = df_rare_1_pre.mean(axis=1)
df_rare_2_pre['mean'] = df_rare_2_pre.mean(axis=1)
df_rare_3_pre['mean'] = df_rare_3_pre.mean(axis=1)
df_rare_4_pre['mean'] = df_rare_4_pre.mean(axis=1)
df_rare_5_pre['mean'] = df_rare_5_pre.mean(axis=1)
df_rare_6_pre['mean'] = df_rare_6_pre.mean(axis=1)
df_rare_7_pre['mean'] = df_rare_7_pre.mean(axis=1)
df_rare_8_pre['mean'] = df_rare_8_pre.mean(axis=1)
df_rare_9_pre['mean'] = df_rare_9_pre.mean(axis=1)
df_rare_10_pre['mean'] = df_rare_10_pre.mean(axis=1)

# %%
df_freq_1_pre['mean'] = df_freq_1_pre.mean(axis=1)
df_freq_2_pre['mean'] = df_freq_2_pre.mean(axis=1)
df_freq_3_pre['mean'] = df_freq_3_pre.mean(axis=1)
df_freq_4_pre['mean'] = df_freq_4_pre.mean(axis=1)
df_freq_5_pre['mean'] = df_freq_5_pre.mean(axis=1)
df_freq_6_pre['mean'] = df_freq_6_pre.mean(axis=1)
df_freq_7_pre['mean'] = df_freq_7_pre.mean(axis=1)
df_freq_8_pre['mean'] = df_freq_8_pre.mean(axis=1)

# %%
df_rare_1_post['mean'] = df_rare_1_post.mean(axis=1)
df_rare_2_post['mean'] = df_rare_2_post.mean(axis=1)
df_rare_3_post['mean'] = df_rare_3_post.mean(axis=1)
df_rare_4_post['mean'] = df_rare_4_post.mean(axis=1)
df_rare_5_post['mean'] = df_rare_5_post.mean(axis=1)
df_rare_6_post['mean'] = df_rare_6_post.mean(axis=1)
df_rare_7_post['mean'] = df_rare_7_post.mean(axis=1)
df_rare_8_post['mean'] = df_rare_8_post.mean(axis=1)
df_rare_9_post['mean'] = df_rare_9_post.mean(axis=1)
df_rare_10_post['mean'] = df_rare_10_post.mean(axis=1)

# %%
df_freq_1_post['mean'] = df_freq_1_post.mean(axis=1)
df_freq_2_post['mean'] = df_freq_2_post.mean(axis=1)
df_freq_3_post['mean'] = df_freq_3_post.mean(axis=1)
df_freq_4_post['mean'] = df_freq_4_post.mean(axis=1)
df_freq_5_post['mean'] = df_freq_5_post.mean(axis=1)
df_freq_6_post['mean'] = df_freq_6_post.mean(axis=1)
df_freq_7_post['mean'] = df_freq_7_post.mean(axis=1)
df_freq_8_post['mean'] = df_freq_8_post.mean(axis=1)
df_freq_9_post['mean'] = df_freq_9_post.mean(axis=1)

# %%
df_rare_1_pre
# Out:
#             A         B         C         D         E         F         G  \
# 0    0.007045 -0.013112 -0.014875 -0.007728 -0.001637 -0.000828 -0.008553
# 1    0.349648  0.790172  0.417562  0.391418  0.401503  0.411400  0.308172
# 2    0.682353  1.563022  0.832591  0.773654  0.787335  0.806827  0.608174
# 3    0.995712  2.276155  1.213443  1.122764  1.139310  1.169401  0.875553
# 4    1.281158  2.902545  1.544594  1.423889  1.442363  1.484526  1.096008
# ..        ...       ...       ...       ...       ...       ...       ...
# 796  0.250322  2.234154  1.971608  1.313570  1.079524  1.122847  1.263759
# 797  0.200702  1.710190  1.512148  1.009284  0.831747  0.858801  0.963086
# 798  0.138583  1.152391  1.022341  0.683184  0.564684  0.579739  0.649584
# 799  0.067749  0.571635  0.511724  0.342127  0.284322  0.290448  0.327468
# 800 -0.007559 -0.020721 -0.009474 -0.006536 -0.002822 -0.004024  0.001028
#
#             H      mean
# 0   -0.008081 -0.005971
# 1    0.253572  0.415431
# ...

# %% [markdown]
# <font color='red'> <font size=5>calculated hilbert transform

# %%
# !pip install spectral
import spectral
from scipy import stats
from scipy.stats import mannwhitneyu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
def bp_filter(data,l,h):
  fs=400.0
  lowcut=l
  highcut=h
  nyq=0.5*fs
  low=lowcut/nyq
  high=highcut/nyq
  b, a = scipy.signal.butter(2,[low,high], 'bandpass', analog=False)
  filteredBandPass = scipy.signal.filtfilt(b, a, data)
  return filteredBandPass

# %%
def orthogo(signal,l,h):
  signal[0]=bp_filter(signal[0],l,h)
  signal[1]=bp_filter(signal[1],l,h)
  ortho=spectral.orthogonalize(signal)
  return ortho

# %%
def AE(signal,l,h):
  signal=orthogo(signal,l,h)
  fs = 400.0
  t=np.arange(start=0,stop=801 , step=1)
  analytic_signal = hilbert(signal)
  amplitude_envelope = np.abs(analytic_signal)
  instantaneous_phase = np.unwrap(np.angle(analytic_signal))
  instantaneous_frequency = (np.diff(instantaneous_phase) /(2.0*np.pi) * fs)
  return amplitude_envelope

# %%
def corre(signal,l,h):
  amp_env=AE(signal,l,h)
  corr=np.corrcoef(amp_env[0],amp_env[1])
  return corr[0,1]

# %%
signal = np.zeros((2, 801))
signal[0]=df_rare_1_pre['mean']
signal[1]=df_rare_2_pre['mean']
ae=AE(signal,4,7)
plt.figure(figsize=(10,5))
plt.plot(signal[0])
plt.title('original signal 1')
plt.figure(figsize=(10,5))
plt.plot(ae[0])
plt.title('Amplitude envelope  signal 1')
plt.figure(figsize=(10,5))
plt.plot(signal[1])
plt.title('original signal 2')
plt.figure(figsize=(10,5))
plt.plot(ae[1])
plt.title('Amplitude envelope signal 2')
# Out:
# Text(0.5, 1.0, 'Amplitude envelope signal 2')

# %%
corr_mat_rare_pre_theta=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_pre,df_rare_2_pre,df_rare_3_pre,df_rare_4_pre,df_rare_5_pre,df_rare_6_pre,df_rare_7_pre,df_rare_8_pre,df_rare_9_pre,df_rare_10_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_pre_theta[m][n]=corre(signal,4,7)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_pre_theta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare pre theta(4-7 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare pre theta(4-7 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_pre_theta[i], corr_mat_rare_pre_theta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 5

# %%
corr_mat_rare_pre_alpha=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_pre,df_rare_2_pre,df_rare_3_pre,df_rare_4_pre,df_rare_5_pre,df_rare_6_pre,df_rare_7_pre,df_rare_8_pre,df_rare_9_pre,df_rare_10_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_pre_alpha[m][n]=corre(signal,8,13)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_pre_alpha, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare pre alpha(8-13 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare pre alpha(8-13 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_pre_alpha[i], corr_mat_rare_pre_alpha[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 2

# %%
corr_mat_rare_pre_beta=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_pre,df_rare_2_pre,df_rare_3_pre,df_rare_4_pre,df_rare_5_pre,df_rare_6_pre,df_rare_7_pre,df_rare_8_pre,df_rare_9_pre,df_rare_10_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_pre_beta[m][n]=corre(signal,15,30)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_pre_beta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare pre beta(15-30 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare pre beta(15-30 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_pre_beta[i], corr_mat_rare_pre_beta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 5

# %%
corr_mat_rare_pre_gamma=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_pre,df_rare_2_pre,df_rare_3_pre,df_rare_4_pre,df_rare_5_pre,df_rare_6_pre,df_rare_7_pre,df_rare_8_pre,df_rare_9_pre,df_rare_10_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_pre_gamma[m][n]=corre(signal,31,45)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_pre_gamma, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare pre gamma(31-45 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare pre gamma(31-45 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_pre_gamma[i], corr_mat_rare_pre_gamma[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 14

# %%
corr_mat_rare_post_theta=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_post,df_rare_2_post,df_rare_3_post,df_rare_4_post,df_rare_5_post,df_rare_6_post,df_rare_7_post,df_rare_8_post,df_rare_9_post,df_rare_10_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_post_theta[m][n]=corre(signal,4,7)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_post_theta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare post theta(4-7 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare post theta(4-7 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_post_theta[i], corr_mat_rare_post_theta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 10

# %%
corr_mat_rare_post_alpha=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_post,df_rare_2_post,df_rare_3_post,df_rare_4_post,df_rare_5_post,df_rare_6_post,df_rare_7_post,df_rare_8_post,df_rare_9_post,df_rare_10_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_post_alpha[m][n]=corre(signal,8,13)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_post_alpha, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare post alpha(8-13 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare post alpha(8-13 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_post_alpha[i], corr_mat_rare_post_alpha[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 0

# %%
corr_mat_rare_post_beta=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_post,df_rare_2_post,df_rare_3_post,df_rare_4_post,df_rare_5_post,df_rare_6_post,df_rare_7_post,df_rare_8_post,df_rare_9_post,df_rare_10_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_post_beta[m][n]=corre(signal,15,30)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_post_beta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare post beta(15-30 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare post beta(15-30 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_post_beta[i], corr_mat_rare_post_beta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 0

# %%
corr_mat_rare_post_gamma=np.zeros((10,10))
m=0
n=0
l=[df_rare_1_post,df_rare_2_post,df_rare_3_post,df_rare_4_post,df_rare_5_post,df_rare_6_post,df_rare_7_post,df_rare_8_post,df_rare_9_post,df_rare_10_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_rare_post_gamma[m][n]=corre(signal,31,45)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_rare_post_gamma, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of rare post gamma(31-45 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of rare post gamma(31-45 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(10):
  for j in range(i+1,10):
    stat, p_value = mannwhitneyu(corr_mat_rare_post_gamma[i], corr_mat_rare_post_gamma[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 5

# %%
corr_mat_freq_pre_theta=np.zeros((8,8))
m=0
n=0
l=[df_freq_1_pre,df_freq_2_pre,df_freq_3_pre,df_freq_4_pre,df_freq_5_pre,df_freq_6_pre,df_freq_7_pre,df_freq_8_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_pre_theta[m][n]=corre(signal,4,7)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_pre_theta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq pre theta(4-7 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq pre theta(4-7 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(8):
  for j in range(i+1,8):
    stat, p_value = mannwhitneyu(corr_mat_freq_pre_theta[i], corr_mat_freq_pre_theta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 5

# %%
corr_mat_freq_pre_alpha=np.zeros((8,8))
m=0
n=0
l=[df_freq_1_pre,df_freq_2_pre,df_freq_3_pre,df_freq_4_pre,df_freq_5_pre,df_freq_6_pre,df_freq_7_pre,df_freq_8_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_pre_alpha[m][n]=corre(signal,8,13)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_pre_alpha, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq pre alpha(8-13 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq pre alpha(8-13 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(8):
  for j in range(i+1,8):
    stat, p_value = mannwhitneyu(corr_mat_freq_pre_alpha[i], corr_mat_freq_pre_alpha[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 0

# %%
corr_mat_freq_pre_beta=np.zeros((8,8))
m=0
n=0
l=[df_freq_1_pre,df_freq_2_pre,df_freq_3_pre,df_freq_4_pre,df_freq_5_pre,df_freq_6_pre,df_freq_7_pre,df_freq_8_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_pre_beta[m][n]=corre(signal,15,30)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_pre_beta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq pre beta(15-30 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq pre beta(15-30 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(8):
  for j in range(i+1,8):
    stat, p_value = mannwhitneyu(corr_mat_freq_pre_beta[i], corr_mat_freq_pre_beta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 0

# %%
corr_mat_freq_pre_gamma=np.zeros((8,8))
m=0
n=0
l=[df_freq_1_pre,df_freq_2_pre,df_freq_3_pre,df_freq_4_pre,df_freq_5_pre,df_freq_6_pre,df_freq_7_pre,df_freq_8_pre]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_pre_gamma[m][n]=corre(signal,31,45)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_pre_gamma, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq pre gamma(31-45 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq pre gamma(31-45 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(8):
  for j in range(i+1,8):
    stat, p_value = mannwhitneyu(corr_mat_freq_pre_gamma[i], corr_mat_freq_pre_gamma[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 5

# %%
corr_mat_freq_post_theta=np.zeros((9,9))
m=0
n=0
l=[df_freq_1_post,df_freq_2_post,df_freq_3_post,df_freq_4_post,df_freq_5_post,df_freq_6_post,df_freq_7_post,df_freq_8_post,df_freq_9_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_post_theta[m][n]=corre(signal,4,7)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_post_theta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq post theta(4-7 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq post theta(4-7 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(9):
  for j in range(i+1,9):
    stat, p_value = mannwhitneyu(corr_mat_freq_post_theta[i], corr_mat_freq_post_theta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 0

# %%
corr_mat_freq_post_alpha=np.zeros((9,9))
m=0
n=0
l=[df_freq_1_post,df_freq_2_post,df_freq_3_post,df_freq_4_post,df_freq_5_post,df_freq_6_post,df_freq_7_post,df_freq_8_post,df_freq_9_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_post_alpha[m][n]=corre(signal,8,13)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_post_alpha, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq post alpha(8-13 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq post alpha(8-13 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(9):
  for j in range(i+1,9):
    stat, p_value = mannwhitneyu(corr_mat_freq_post_alpha[i], corr_mat_freq_post_alpha[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 1

# %%
corr_mat_freq_post_beta=np.zeros((9,9))
m=0
n=0
l=[df_freq_1_post,df_freq_2_post,df_freq_3_post,df_freq_4_post,df_freq_5_post,df_freq_6_post,df_freq_7_post,df_freq_8_post,df_freq_9_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_post_beta[m][n]=corre(signal,15,30)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_post_beta, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq post beta(15-30 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq post beta(15-30 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(9):
  for j in range(i+1,9):
    stat, p_value = mannwhitneyu(corr_mat_freq_post_beta[i], corr_mat_freq_post_beta[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 0

# %%
corr_mat_freq_post_gamma=np.zeros((9,9))
m=0
n=0
l=[df_freq_1_post,df_freq_2_post,df_freq_3_post,df_freq_4_post,df_freq_5_post,df_freq_6_post,df_freq_7_post,df_freq_8_post,df_freq_9_post]
for i in l:
  n=0
  for j in l:
    signal = np.zeros((2, 801))
    signal[0]=i['mean']
    signal[1]=j['mean']
    corr_mat_freq_post_gamma[m][n]=corre(signal,31,45)
    n+=1
  m+=1
plt.figure(figsize=(15,7))
sns.heatmap(corr_mat_freq_post_gamma, vmax=1, annot=True, linewidths=.5, cmap="YlGnBu")
plt.title("Correlation of freq post gamma(31-45 hz)")
# Out:
# Text(0.5, 1.0, 'Correlation of freq post gamma(31-45 hz)')

# %%
count=0
alpha = 0.05
p=[]
for i in range(9):
  for j in range(i+1,9):
    stat, p_value = mannwhitneyu(corr_mat_freq_post_gamma[i], corr_mat_freq_post_gamma[j])
    p.append(p_value)
    
    if p_value < alpha:
        #print(i,j)
        count+=1
print(count)
plt.figure(figsize=(15,7))
plt.plot(p)
plt.axhline(alpha)
plt.show()
# Out:
# 2

# %%
import random
data_1=[]
for i in range(9):
  for j in corr_mat_freq_post_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("freq post")
    data_1.append(temp)
  
data_2=[]
for i in range(8):
  for j in corr_mat_freq_pre_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("freq pre")
    data_2.append(temp)

data_3=[]
for i in range(10):
  for j in corr_mat_rare_pre_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("rare pre")
    data_3.append(temp)

data_4=[]
for i in range(10):
  for j in corr_mat_rare_post_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("rare post")
    data_4.append(temp)

data=data_1+data_2+data_3+data_4
#data
random.shuffle(data)
df=pd.DataFrame(data,columns=['Correlation','Group'])
df
# Out:
#      Correlation      Group
# 0       0.654056   freq pre
# 1       0.420227  freq post
# 2       0.786172   rare pre
# 3       0.250664   freq pre
# 4       0.707369   freq pre
# ..           ...        ...
# 340     0.654617   rare pre
# 341     0.797765  freq post
# 342     0.052280  rare post
# 343     0.056532   rare pre
# 344     0.664354   freq pre
#
# [345 rows x 2 columns]

# %%
plt.scatter(df['Group'], df['Correlation'])

# %%
x=pd.DataFrame(df['Correlation'])
y=pd.DataFrame(df['Group'])
df.describe()
# Out:
#        Correlation
# count   345.000000
# mean      0.580011
# std       0.254130
# min      -0.096560
# 25%       0.444920
# 50%       0.651042
# 75%       0.788001
# max       0.929906

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
x_train
# Out:
#      Correlation
# 49      0.836139
# 237     0.802971
# 326     0.756139
# 122     0.423835
# 168     0.848481
# ..           ...
# 323     0.747573
# 192     0.536633
# 117     0.554086
# 47      0.620496
# 172     0.725198
#
# [276 rows x 1 columns]

# %%
x_train = x_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import accuracy_score
lda = LDA(n_components=1)
x_train = lda.fit_transform(x_train, y_train)
x_test = lda.transform(x_test)
# lda.fit(x_train,y_train)
# y_pred=lda.predict(x_test)
# print('Accuracy '+ str(accuracy_score(y_test,y_pred)))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)

classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy ' + str(accuracy_score(y_test, y_pred)))
# Out:
# [[ 7  0  6  5]
#  [ 7  0  3  1]
#  [ 7  0 10  4]
#  [ 9  0  6  4]]
# Accuracy 0.30434782608695654

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression(solver='liblinear', random_state=0)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy 0.36231884057971014
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn import svm
model = svm.SVC(kernel='poly', degree=2)
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy 0.34782608695652173
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
import lightgbm as ltb
model = ltb.LGBMClassifier()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy 0.37681159420289856

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
print("Training Accuracy of KNN: ", knn.score(x_train,y_train))
y_pred=knn.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Training Accuracy of KNN:  0.5144927536231884
# Accuracy 0.2608695652173913
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
print("Training Accuracy of Decision Tree: ", dt.score(x_train,y_train))
y_pred=dt.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Training Accuracy of Decision Tree:  1.0
# Accuracy 0.30434782608695654

# %%
import random
data_1=[]
for i in range(9):
  for j in corr_mat_freq_post_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("freq")
    data_1.append(temp)
  
data_2=[]
for i in range(8):
  for j in corr_mat_freq_pre_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("freq")
    data_2.append(temp)

data_3=[]
for i in range(10):
  for j in corr_mat_rare_pre_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("rare")
    data_3.append(temp)

data_4=[]
for i in range(10):
  for j in corr_mat_rare_post_gamma[i]:
    temp=[]
    temp.append(j)
    temp.append("rare")
    data_4.append(temp)

data=data_1+data_2+data_3+data_4
#data
random.shuffle(data)
df=pd.DataFrame(data,columns=['Correlation','Group'])
df
# Out:
#      Correlation Group
# 0       0.282436  freq
# 1       0.056532  rare
# 2       0.051285  rare
# 3       0.815995  rare
# 4       0.376007  freq
# ..           ...   ...
# 340     0.881451  rare
# 341     0.867827  rare
# 342     0.731448  freq
# 343     0.747573  freq
# 344     0.654056  freq
#
# [345 rows x 2 columns]

# %%
x=pd.DataFrame(df['Correlation'])
y=pd.DataFrame(df['Group'])
df.describe()
# Out:
#        Correlation
# count   345.000000
# mean      0.580011
# std       0.254130
# min      -0.096560
# 25%       0.444920
# 50%       0.651042
# 75%       0.788001
# max       0.929906

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
x_train = x_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
model = LogisticRegression(solver='liblinear', random_state=0)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy 0.5217391304347826
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
import lightgbm as ltb
model = ltb.LGBMClassifier()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy 0.6231884057971014
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
print("Training Accuracy of Decision Tree: ", dt.score(x_train,y_train))
y_pred=dt.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Training Accuracy of Decision Tree:  1.0
# Accuracy 0.5507246376811594

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
print("Training Accuracy of KNN: ", knn.score(x_train,y_train))
y_pred=knn.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Training Accuracy of KNN:  0.6920289855072463
# Accuracy 0.5942028985507246
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
# from sklearn.preprocessing import StandardScaler

# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.transform(x_test)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import accuracy_score
lda = LDA(n_components=1)
x_train = lda.fit_transform(x_train, y_train)
x_test = lda.transform(x_test)
y_pred=lda.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy 0.5217391304347826
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=2, random_state=0)

classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# Accuracy 0.6231884057971014

# %%
from sklearn import svm
model = svm.SVC(kernel='poly', degree=2)
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
print('Accuracy '+str(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy 0.5217391304347826
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# <font color='red'> <font size=5>calculated synchrony

# %%
def signal_synchrony(signal1, signal2, method="hilbert", window_size=50):
    """Compute the synchrony (coupling) between two signals.

    Compute a continuous index of coupling between two signals either using the 'Hilbert' method to get
    the instantaneous phase synchrony, or using rolling window correlation.

    The instantaneous phase synchrony measures the phase similarities between signals at each timepoint.
    The phase refers to the angle of the signal, calculated through the hilbert transform, when it is
    resonating between -pi to pi degrees. When two signals line up in phase their angular difference becomes zero.

    For less clean signals, windowed correlations are widely used because of their simplicity, and can
    be a good a robust approximation of synchrony between two signals. The limitation is the need to select a window.



    Parameters
    ----------
    signal1 : Union[list, np.array, pd.Series]
        Time series in the form of a vector of values.
    signal2 : Union[list, np.array, pd.Series]
        Time series in the form of a vector of values.
    method : str
        The method to use. Can be one of 'hilbert' or 'correlation'.
    window_size : int
        Only used if `method='correlation'`. The number of samples to use for rolling correlation.

    See Also
    --------
    signal_filter, signal_zerocrossings, signal_findpeaks

    Returns
    -------
    array
        A vector containing the phase of the signal, between 0 and 2*pi.

    Examples
    --------
    >>> import neurokit2 as nk
    >>>
    >>> signal1 = nk.signal_simulate(duration=10, frequency=1)
    >>> signal2 = nk.signal_simulate(duration=10, frequency=1.5)
    >>>
    >>> coupling_h = nk.signal_synchrony(signal1, signal2, method="hilbert")
    >>> coupling_c = nk.signal_synchrony(signal1, signal2, method="correlation", window_size=1000/2)
    >>>
    >>> fig = nk.signal_plot([signal1, signal2, coupling_h, coupling_c])
    >>> fig #doctest: +SKIP

    References
    ----------
    -  http://jinhyuncheong.com/jekyll/update/2017/12/10/Timeseries_synchrony_tutorial_and_simulations.html

    """
    if method.lower() in ["hilbert", "phase"]:
        coupling = _signal_synchrony_hilbert(signal1, signal2)
    elif method.lower() in ["correlation"]:
        coupling = _signal_synchrony_correlation(signal1, signal2, window_size=int(window_size))

    else:
        raise ValueError("NeuroKit error: signal_synchrony(): 'method' should be one of 'hilbert' or 'correlation'.")

    return coupling



# =============================================================================
# Methods
# =============================================================================


def _signal_synchrony_hilbert(signal1, signal2):

    hill1 = scipy.signal.hilbert(signal1)
    hill2 = scipy.signal.hilbert(signal2)

    phase1 = np.angle(hill1, deg=False)
    phase2 = np.angle(hill2, deg=False)
    synchrony = 1 - np.sin(np.abs(phase1 - phase2) / 2)

    return synchrony


def _signal_synchrony_correlation(signal1, signal2, window_size, center=False):
    """Calculates pairwise rolling correlation at each time. Grabs the upper triangle, at each timepoints.

    - window: window size of rolling corr in samples
    - center: whether to center result (Default: False, so correlation values are listed on the right.)

    """
    data = pd.DataFrame({"y1": signal1, "y2": signal2})

    rolled = data.rolling(window=window_size, center=center).corr()
    synchrony = rolled["y1"].loc[rolled.index.get_level_values(1) == "y2"].values

    # Realign
    synchrony = np.append(synchrony[int(window_size / 2) :], np.full(int(window_size / 2), np.nan))
    synchrony[np.isnan(synchrony)] = np.nanmean(synchrony)

    return synchrony

# %%
#signal_synchrony(df_rare_2_pre['mean'] , df_rare_1_pre['mean'])
plt.plot(signal_synchrony(df_rare_2_pre['mean'] , df_rare_1_pre['mean']))

# %%
N=801
y1 = df_rare_1_pre['mean']
y2 = df_rare_2_pre['mean']

al1 = np.angle(hilbert(y1),deg=False)
al2 = np.angle(hilbert(y2),deg=False)
f,ax = plt.subplots(2,1,figsize=(20,5),sharex=True)
#ax[0].plot(y1,color='r',label='y1')
#ax[0].plot(y2,color='b',label='y2')
#ax[0].legend(bbox_to_anchor=(0., 1.02, 1., .102),ncol=2)
#ax[0].set(xlim=[0,N], title='Timeseries Data')
ax[0].plot(al1,color='r')
ax[0].plot(al2,color='b')
ax[0].set(title='Angle at each Timepoint')
phase_synchrony = 1-np.sin(np.abs(al1-al2)/2)
ax[1].plot(phase_synchrony)
ax[1].set(ylim=[0,1.1],xlim=[0,N],title='Instantaneous Phase Synchrony',xlabel='Time',ylabel='Phase Synchrony')
plt.tight_layout()
plt.show()

# %%
def get_triangle(df,k=0):
    '''
    This function grabs the upper triangle of a correlation matrix
    by masking out the bottom triangle (tril) and returns the values.

    df: pandas correlation matrix
    '''
    x = np.hstack(df.mask(np.tril(np.ones(df.shape),k=k).astype(np.bool)).values.tolist())
    x = x[~np.isnan(x)]
    return x  

def rolling_correlation(data, wrap=False, *args, **kwargs):
    '''
    Intersubject rolling correlation.
    Data is dataframe with observations in rows, subjects in columns.
    Calculates pairwise rolling correlation at each time.
    Grabs the upper triangle, at each timepoints returns dataframe with
    observation in rows and pairs of subjects in columns.
    *args:
        window: window size of rolling corr in samples
        center: whether to center result (Default: False, so correlation values are listed on the right.)
    '''
    data_len = data.shape[0]
    half_data_len = int(data.shape[0]/2)
    start_len = data.iloc[half_data_len:].shape[0]
    if wrap:
        data = pd.concat([data.iloc[half_data_len:],data,data.iloc[:half_data_len]],axis=0).reset_index(drop=True)
    _rolling = data.rolling(*args, **kwargs).corr()       
    rs=[]
    for i in np.arange(0,data.shape[0]):
        rs.append(get_triangle(_rolling.loc[i]))
    rs = pd.DataFrame(rs)   
    rs = rs.iloc[start_len:start_len+data_len].reset_index(drop=True)
    return rs  
y1 = df_rare_1_pre['mean']
y2 = df_rare_2_pre['mean']
N = 801
window_size = 50
al1 = np.angle(hilbert(y1),deg=False)
al2 = np.angle(hilbert(y2),deg=False)
f,ax = plt.subplots(2,1,figsize=(20,5),sharex=True)
ax[0].plot(y1,color='r',label='y1')
ax[0].plot(y2,color='b',label='y2')
ax[0].legend(bbox_to_anchor=(0., 1.02, 1., .102),ncol=2)
ax[0].set(xlim=[0,N], title='Timeseries Data')
window_corr_synchrony = rolling_correlation(data=pd.DataFrame({'y1':y1,'y2':y2}),wrap=True,window=window_size,center=True)
window_corr_synchrony.plot(ax=ax[1],legend=False)
ax[1].set(ylim=[-1.1,1.1],xlim=[0,N],title='Windowed Correlation Synchrony (size: '+str(window_size)+')',xlabel='Time',ylabel='Correlation Synchrony')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import numpy as np
import scipy.signal as sig
y1 = df_rare_1_pre['mean']
y2 = df_rare_2_pre['mean']
def hilphase(y1,y2):
    sig1_hill=sig.hilbert(y1)
    sig2_hill=sig.hilbert(y2)
    pdt=(np.inner(sig1_hill,np.conj(sig2_hill))/(np.sqrt(np.inner(sig1_hill,
               np.conj(sig1_hill))*np.inner(sig2_hill,np.conj(sig2_hill)))))
    phase = np.angle(pdt)

    return phase
print(hilphase(y1,y2))
# Out:
# 2.6477124385249096

# %%
import numpy as np
import scipy.signal as sig
y1 = df_rare_3_pre['mean']
y2 = df_rare_2_pre['mean']
def hilphase(y1,y2):
    sig1_hill=sig.hilbert(y1)
    sig2_hill=sig.hilbert(y2)
    pdt=(np.inner(sig1_hill,np.conj(sig2_hill))/(np.sqrt(np.inner(sig1_hill,
               np.conj(sig1_hill))*np.inner(sig2_hill,np.conj(sig2_hill)))))
    phase = np.abs(np.angle(pdt))

    return phase
print(hilphase(y1,y2))
# Out:
# 1.0140700515676906

# %%
req_list=[df_rare_1_pre['mean'],df_rare_2_pre['mean'],df_rare_3_pre['mean'],df_rare_4_pre['mean'],df_rare_5_pre['mean'],df_rare_6_pre['mean'],df_rare_7_pre['mean'],df_rare_8_pre['mean'],df_rare_9_pre['mean'],df_rare_10_pre['mean']]

# %%
df_pd= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])
def hilphase_diff(y1,y2):
    sig1_hill=sig.hilbert(y1)
    sig2_hill=sig.hilbert(y2)
    pdt=(np.inner(sig1_hill,np.conj(sig2_hill))/(np.sqrt(np.inner(sig1_hill,
               np.conj(sig1_hill))*np.inner(sig2_hill,np.conj(sig2_hill)))))
    phase = np.abs(np.angle(pdt))
    return phase
for i in range(0,10):
    for j in range(0,10):
        y1 = req_list[i]
        y2 = req_list[j]
        df_pd = df_pd.append({'region1': "reg-{}".format(i), 'region2': "reg-{}".format(j), 'value':hilphase_diff(y1,y2)}, ignore_index=True)
        #print(hilphase(y1,y2))

# %%
df_pivot=df_pd.pivot_table(index='region1', columns='region2', values='value', fill_value=0)

# %%
def normalize(lis, min, max):
    req=[]
    for value in lis:
        normalized = (value - min) / (max - min);
        req.append(normalized)
    return req;
df_pd.insert(loc=3,column="normalized",value=normalize(df_pd['value'], min(df_pd['value']), max(df_pd['value'])))
df_pivot_norma=df_pd.pivot_table(index='region1', columns='region2', values='normalized', fill_value=0)
#fig, ax = plt.subplots(figsize=(8,8)) 
#mask = np.zeros_like(df_pivot, dtype=np.bool)
#mask[np.triu_indices_from(mask)] = True
#mask[np.diag_indices_from(mask)] = False
#sns.heatmap(df_pivot , annot=True, cmap="Blues_r" , mask=mask)
fig, ax = plt.subplots(figsize=(8,8))
mask = np.zeros_like(df_pivot_norma, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False
sns.heatmap(df_pivot_norma , annot=True, cmap="YlOrBr_r" , mask=mask)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ipykernel import kernelapp as app

# %%
req_list=[df_rare_1_pre['mean'],df_rare_2_pre['mean'],df_rare_3_pre['mean'],df_rare_4_pre['mean'],df_rare_5_pre['mean'],df_rare_6_pre['mean'],df_rare_7_pre['mean'],df_rare_8_pre['mean'],df_rare_9_pre['mean'],df_rare_10_pre['mean']]
df_plv_new= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])
def plv(y1,y2):
    analytic_signal_1 = hilbert(y1)
    theta1 = np.unwrap(np.angle(analytic_signal_1))
    analytic_signal_2 = hilbert(y2)
    theta2 = np.unwrap(np.angle(analytic_signal_2))
    complex_phase_diff = np.exp(np.complex(0,1)*(theta1 - theta2))
    plv = np.abs(np.sum(complex_phase_diff))/len(theta1)
    return plv

for i in range(0,10):
    for j in range(0,10):
        y1 = req_list[i]
        y2 = req_list[j]
        df_plv_new = df_plv_new.append({'region1': "reg-{}".format(i+1), 'region2': "reg-{}".format(j+1), 'value':plv(y1,y2)}, ignore_index=True)
        #print(hilphase(y1,y2))
df_pivot_new=df_plv_new.pivot_table(index='region1', columns='region2', values='value', fill_value=0)      
#print(plv(df_rare_2_pre['mean'],df_rare_1_pre['mean']))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
fig, ax = plt.subplots(figsize=(8,8)) 
mask = np.zeros_like(df_pivot_new, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False
ax = plt.axes()

sns.heatmap(df_pivot_new , annot=True, cmap="Blues" , mask=mask , ax = ax)
ax.set_title('For pre-stimulus rare perceivers')
plt.show()
#plt.title("For pre-stimulus rare perceivers")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
req_list=[df_freq_1_pre['mean'],df_freq_2_pre['mean'],df_freq_3_pre['mean'],df_freq_4_pre['mean'],df_freq_5_pre['mean'],df_freq_6_pre['mean'],df_freq_7_pre['mean'],df_freq_8_pre['mean']]

df_pd= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])



df_plv_new= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])

for i in range(0,8):
    for j in range(0,8):
        y1 = req_list[i]
        y2 = req_list[j]
        df_plv_new = df_plv_new.append({'region1': "reg-{}".format(i+1), 'region2': "reg-{}".format(j+1), 'value':plv(y1,y2)}, ignore_index=True)
        #print(hilphase(y1,y2))
df_pivot_new=df_plv_new.pivot_table(index='region1', columns='region2', values='value', fill_value=0)      
#print(plv(df_freq_2_pre['mean'],df_freq_1_pre['mean']))

fig, ax = plt.subplots(figsize=(8,8)) 
mask = np.zeros_like(df_pivot_new, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False
ax = plt.axes()

sns.heatmap(df_pivot_new , annot=True, cmap="Blues" , mask=mask , ax = ax)
ax.set_title('For pre-stimulus freq perceivers')
plt.show()
#plt.title("For pre-stimulus freq perceivers")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
req_list=[df_rare_1_post['mean'],df_rare_2_post['mean'],df_rare_3_post['mean'],df_rare_4_post['mean'],df_rare_5_post['mean'],df_rare_6_post['mean'],df_rare_7_post['mean'],df_rare_8_post['mean'],df_rare_9_post['mean'],df_rare_10_post['mean']]

df_pd= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])



df_plv_new= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])

for i in range(0,10):
    for j in range(0,10):
        y1 = req_list[i]
        y2 = req_list[j]
        df_plv_new = df_plv_new.append({'region1': "reg-{}".format(i+1), 'region2': "reg-{}".format(j+1), 'value':plv(y1,y2)}, ignore_index=True)
        #print(hilphase(y1,y2))
df_pivot_new2=df_plv_new.pivot_table(index='region1', columns='region2', values='value', fill_value=0)      
#print(plv(df_rare_2_post['mean'],df_rare_1_post['mean']))

fig, ax = plt.subplots(figsize=(8,8)) 
mask = np.zeros_like(df_pivot_new2, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False
ax = plt.axes()

sns.heatmap(df_pivot_new2 , annot=True, cmap="Blues" , mask=mask , ax = ax)
ax.set_title('For post-stimulus rare perceivers')
plt.show()
#plt.title("For post-stimulus rare perceivers")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
#####test


req_list=[df_rare_1_post['mean'],df_rare_2_post['mean'],df_rare_3_post['mean'],df_rare_4_post['mean'],df_rare_5_post['mean'],df_rare_6_post['mean'],df_rare_7_post['mean'],df_rare_8_post['mean'],df_rare_9_post['mean']]

df_pd= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])



df_plv_new= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])

for i in range(0,9):
    for j in range(0,9):
        y1 = req_list[i]
        y2 = req_list[j]
        df_plv_new = df_plv_new.append({'region1': "reg-{}".format(i+1), 'region2': "reg-{}".format(j+1), 'value':plv(y1,y2)}, ignore_index=True)
        #print(hilphase(y1,y2))
df_pivot_new2=df_plv_new.pivot_table(index='region1', columns='region2', values='value', fill_value=0)      
#print(plv(df_rare_2_post['mean'],df_rare_1_post['mean']))

fig, ax = plt.subplots(figsize=(8,8)) 
mask = np.zeros_like(df_pivot_new2, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False
ax = plt.axes()

sns.heatmap(df_pivot_new2 , annot=True, cmap="Blues" , mask=mask , ax = ax)
ax.set_title('For post-stimulus rare perceivers')
plt.show()
#plt.title("For post-stimulus rare perceivers")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
req_list=[df_freq_1_post['mean'],df_freq_2_post['mean'],df_freq_3_post['mean'],df_freq_4_post['mean'],df_freq_5_post['mean'],df_freq_6_post['mean'],df_freq_7_post['mean'],df_freq_8_post['mean'],df_freq_9_post['mean']]

df_pd= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])



df_plv_new= pd.DataFrame(columns=['region1' , 'region2' , 'region3'])

for i in range(0,9):
    for j in range(0,9):
        y1 = req_list[i]
        y2 = req_list[j]
        df_plv_new = df_plv_new.append({'region1': "reg-{}".format(i+1), 'region2': "reg-{}".format(j+1), 'value':plv(y1,y2)}, ignore_index=True)
        #print(hilphase(y1,y2))
df_pivot_new1=df_plv_new.pivot_table(index='region1', columns='region2', values='value', fill_value=0)      
#print(plv(df_freq_2_post['mean'],df_freq_1_post['mean']))

fig, ax = plt.subplots(figsize=(8,8)) 
mask = np.zeros_like(df_pivot_new1, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False
ax = plt.axes()

sns.heatmap(df_pivot_new1 , annot=True, cmap="Blues" , mask=mask , ax = ax)
ax.set_title('For post-stimulus freq perceivers')
plt.show()
#plt.title("For post-stimulus freq perceivers")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# Mann-Whitney U test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu
# seed the random number generator
seed(1)
# generate two independent samples

stat, p = mannwhitneyu(signal_synchrony(df_rare_1_post['mean'] , df_rare_6_post['mean']), signal_synchrony(df_rare_1_pre['mean'] , df_rare_6_pre['mean']))
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=546565.000, p=0.000
# Different distribution (reject H0)

# %%
# Mann-Whitney U test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu
# seed the random number generator
seed(1)
# generate two independent samples

stat, p = mannwhitneyu(signal_synchrony(df_rare_1_post['mean'] , df_rare_8_post['mean']), signal_synchrony(df_freq_1_pre['mean'] , df_freq_8_pre['mean']))
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.0000000005
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=470153.000, p=0.000
# Different distribution (reject H0)

# %%
# Mann-Whitney U test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu
# seed the random number generator
seed(1)
# generate two independent samples

stat, p = mannwhitneyu(signal_synchrony(df_rare_1_post['mean'] , df_rare_2_post['mean']), signal_synchrony(df_rare_1_pre['mean'] , df_rare_2_pre['mean']))
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=395542.000, p=0.000
# Different distribution (reject H0)

# %%
req_list_rare=[df_freq_1_post['mean'],df_freq_2_post['mean'],df_freq_3_post['mean'],df_freq_4_post['mean'],df_freq_5_post['mean'],df_freq_6_post['mean'],df_freq_7_post['mean'],df_freq_8_post['mean'],df_freq_9_post['mean']]
req_list_freq=[df_rare_1_post['mean'],df_rare_2_post['mean'],df_rare_3_post['mean'],df_rare_4_post['mean'],df_rare_5_post['mean'],df_rare_6_post['mean'],df_rare_7_post['mean'],df_rare_8_post['mean'],df_rare_9_post['mean']]



from numpy.random import seed
from numpy.random import randn
from scipy.stats import mannwhitneyu
df_stat=pd.DataFrame(columns=['region1' , 'region2' , 'stat','P value' , 'result'])
alpha = 0.05
for i in range(0,9):
    for j in range(0,9):
        if (i==j):
            pass
        else:
            stat, p = mannwhitneyu(signal_synchrony( req_list_rare[i] ,  req_list_rare[j]), signal_synchrony(req_list_freq[i] ,  req_list_freq[j]))
            if p > alpha:
                ##print('Same distribution (fail to reject H0)')
                df_stat = df_stat.append({'region1': "reg-{}".format(i+1), 'region2': "reg-{}".format(j+1), 'P value':p , 'stat' : stat , 'result':'Same distribution (fail to reject H0)'}, ignore_index=True)
            else:
                ##print('Different distribution (reject H0)')
                df_stat = df_stat.append({'region1': "reg-{}".format(i+1), 'region2': "reg-{}".format(j+1), 'P value':p , 'stat' : stat , 'result':'Different distribution (reject H0)'}, ignore_index=True)

# %%
df_stat
# Out:
#    region1 region2      stat        P value  \
# 0    reg-1   reg-2  384050.0   8.376502e-12
# 1    reg-1   reg-3   69293.0  1.595422e-162
# 2    reg-1   reg-4  527388.0  2.650203e-110
# 3    reg-1   reg-5  156772.0   3.057354e-70
# 4    reg-1   reg-6   60944.0  2.354403e-173
# ..     ...     ...       ...            ...
# 67   reg-9   reg-4  472622.0   1.937090e-60
# 68   reg-9   reg-5  288970.0   5.856490e-04
# 69   reg-9   reg-6  152707.0   1.133040e-73
# 70   reg-9   reg-7  246407.0   9.305031e-16
# 71   reg-9   reg-8  384418.0   6.343887e-12
#
#                                 result
# 0   Different distribution (reject H0)
# 1   Different distribution (reject H0)
# 2   Different distribution (reject H0)
# 3   Different distribution (reject H0)
# 4   Different distribution (reject H0)
# ..                                 ...
# 67  Different distribution (reject H0)
# 68  Different distribution (reject H0)
# 69  Different distribution (reject H0)
# ...
